# %%
local_path = "C:/Users/jongb/OneDrive/바탕 화면/temp/google_openpaper/test.pdf"

# %%
import os
folder_path = os.path.dirname(local_path).replace("\\", "/")
folder_path
# Out:
# 'C:/Users/jongb/OneDrive/바탕 화면/temp/google_openpaper'

# %%
server_path = local_path.replace(folder_path, "").replace("/", "")
server_path
# Out:
# 'test.pdf'
