# %%
import pickle

# %%
path = "D:/auto_vectordb/backend/docs/parsed/project01/cat_01/cat_01_01/FWG.pkl"
# path = "D:/auto_vectordb/backend/docs/project01/cat_02/cat_02_01/cat_02_01_01/Unit_Cooler.pkl"

# %%
path = path.replace("\\", "/")
with open(path, 'rb') as f:
    data = pickle.load(f)

# %%
data
# Out:
# [Document(metadata={'id': '218d0e2e-dd6d-4d70-9986-ce937ff86954', 'filename': 'FWG.pdf', 'filepath': 'D:/auto_vectordb/backend/docs/uploaded/project01/cat_01/cat_01_01/FWG.pdf', 'hashed_filename': 'bae0b5904782ab6893ab0a1c778c050b', 'hashed_filepath': '5476ca42f4dd6e62009b59289f1c7f84', 'hashed_page_content': '35187770084da2ca566c3861de6fb471', 'lv1_cat': 'project01', 'lv2_cat': 'cat_01', 'lv3_cat': 'cat_01_01', 'lv4_cat': '', 'embeddings': [-0.073048696, -0.04837103, -0.017155832, 0.0049478984, 0.0012404249, -0.073114775, -0.03916315, 0.0028388714, -0.035958435, 0.021374187, 0.0029740802, 0.02565004, 0.010969692, 0.018317593, -0.03450307, -0.03705245, 0.013167514, 0.0029505237, -0.00593646, -0.019350583, -0.027036564, -0.03353311, 0.0344486, 0.021632235, -0.00179367, 0.021467574, 0.002952602, -0.0030142153, -4.27305e-05, 0.0024013892, 0.035579067, -0.027726917, 0.024203723, -0.04455697, -0.0064881183, -0.061974194, 0.015640387, -0.005628821, -0.049699493, 0.0013447029, -0.021762878,
# ...

# %%
from IPython.display import Markdown
print(data[1].metadata)
Markdown(data[1].page_content)
# Out:
# {'id': '7fec2cf1-71b3-4892-b909-f0801f9f5f10', 'filename': 'FWG.pdf', 'filepath': 'D:/auto_vectordb/backend/docs/uploaded/project01/cat_01/cat_01_01/FWG.pdf', 'hashed_filename': 'bae0b5904782ab6893ab0a1c778c050b', 'hashed_filepath': '5476ca42f4dd6e62009b59289f1c7f84', 'hashed_page_content': 'dff8e64b4847d0ac01013d98403ab86f', 'lv1_cat': 'project01', 'lv2_cat': 'cat_01', 'lv3_cat': 'cat_01_01', 'lv4_cat': '', 'embeddings': [-0.060106765, -0.024933968, -0.027961807, 0.020272216, 0.0088486, -0.09173392, -0.051771495, 0.008657079, -0.022901695, 0.011606831, -0.01551297, 0.029838176, -0.023638034, -0.021560717, -0.021006998, -0.007019893, -0.025403906, -0.014648796, 0.002611043, -0.016094415, -0.02087663, -0.046353705, 0.034206335, 0.02852181, 0.011833357, 0.0012365371, -0.029621575, -0.023195093, 0.012323605, 0.0009220128, 0.02351594, -0.023035381, -0.01708093, -0.011273751, -0.018843103, -0.017737731, 0.003882136, 0.0012430734, -0.040237155, -0.008450999, -0.024131637, -0.008785474, 0.0
# ...

# %%
data[1].metadata["filepath"]
# Out:
# 'D:/auto_vectordb/backend/uploaded/project01/cat_01/cat_01_01/FWG.pdf'
